# %%
import pandas as pd

# %%
data = pd.read_csv('https://github.com/KamatMayur/EmotionAnalysis/raw/main/main/saved%20data/tokenized_text.csv')

# %%
data
# Out:
#        Unnamed: 0                                               text  \
# 0               0                                    That game hurt.
# 1               1     You do right, if you don't care then fuck 'em!
# 2               2                                 Man I love reddit.
# 3               3  [NAME] was nowhere near them, he was by the Fa...
# 4               4  Right? Considering it’s such an important docu...
# ...           ...                                                ...
# 35029       35029  When I harass women with innuendo and they pol...
# 35030       35030                            You’re good, no worries
# 35031       35031  one's a rapist, and the other's a stingy yank ...
# 35032       35032  This is great! Can anyone make a request with ...
# 35033       35033                                No but it should be
#
#          Emotions  Emotion_id  \
# 0         sadness          26
# 1         neutral          20
# 2            love          18
# 3         neutral          20
# 4       gratitude          15
# ...           ...         ...
# 35029     neutral          20
# 35030  admiration           0
# 35031   annoyance           3
# 35032  admiration           0
# 35033     neutral          20
#
#                                                tokenized
# 0                                       ['game', 'hurt']
# 1                ['right', 'dont', 'care', 'fuck', 'em']
# 2                              ['man', 'love', 'reddit']
# 3                   ['name', 'nowher', 'near', 'falcon']
# 4      ['right', 'consid', '’', 'import', 'document',...
# ...                                                  ...
# 35029  ['harass', 'women', 'innuendo', 'polit', 'defl...
# 35030                             ['’', 'good', 'worri']
# 35031  ['one', 'rapist', 'other', 'stingi', 'yank', '...
# 35032      ['great', 'anyon', 'make', 'request', 'draw']
# 35033                                                 []
#
# [35034 rows x 5 columns]
